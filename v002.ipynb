# %% [markdown]
# # Game Sales Data Visualization

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.core.display import display, HTML

pd.set_option("display.max_rows",2000)
pd.set_option("display.max_column",2000)

# %% [markdown]
# ### Buraya kadar olan kısımda (1-6) kütüphaneleri import ettik.

# %% [markdown]
# ### Satır ve sütun genişliklerini ayarladık

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# ### Train.csv  dosyası programa tanıtıldı ve df değişkenini atadık.

# %%
print(df.head(5))
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
Birleştir
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9018f216efff> in <module>
# ----> 1 Birleştir
#
# NameError: name 'Birleştir' is not defined

# %%
print(df.shape)
# Out:
# (16719, 16)

# %%
print(df.isnull().sum())
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB
# None

# %% [markdown]
# ### Çeşitli bilgiler girildi.

# %%
16-20 tek bir hücre
# Out:
#   File "<ipython-input-12-f75ddafd3b5c>", line 1
#     16-20 tek bir hücre
#             ^
# SyntaxError: invalid syntax

# %%
#Shows Missing Data as Percent# (Eksik olan dataları yüzde olarak gösterir)

# %%
sns.set_style("whitegrid")
missing = df.isnull().sum()
missing = (missing[missing > 0]) / 16719
missing.sort_values(inplace=True)
missing.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Eksik datalara bakılarak grafikler girildi.

# %%
# Annotated heatmap of all correlation coefficients between variables ??

# %%
plt.subplots(figsize=(8,8))
sns.heatmap(df.corr(), annot=True, fmt=".2f")
plt.show()

# %% [markdown]
# ### Grafikler çizildi.

# %%
groupby_platform
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-b61972156b25> in <module>
# ----> 1 groupby_platform
#
# NameError: name 'groupby_platform' is not defined

# %%
total_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-2dbcb7e35c17> in <module>
# ----> 1 total_data.head()
#
# NameError: name 'total_data' is not defined

# %%
total_data = df.dropna(subset=['Critic_Score', "Developer" ,"Critic_Count" ,"User_Score","User_Count","Rating"])
groupby_platform = total_data.groupby(['Platform']).size().reset_index()
all_platform=df.groupby(['Platform']).size().reset_index()
groupby_platform.plot.bar(x="Platform", figsize= (15, 7))
plt.show()

# %% [markdown]
# ### Grafikleri çıkarttık.

# %%
d = {'Platform': [], 'Yüzde': []}

# %%
final = pd.DataFrame(data = d)

# %% [markdown]
# ### Final değişkenleri

# %%
for i in range(len(all_platform)):
    for j in range(len(groupby_platform)):
        if all_platform["Platform"][i] == groupby_platform["Platform"][j]:
           b = groupby_platform[0][j] / all_platform[0][i] * 100
           final.at[j , "Platform"] = groupby_platform["Platform"][j]
           final.at[j , "Percent"] = b
         final.plot.barh(x = "Platform" , figsize=(15,7) , color = "red", title = "% ")
            plt.show()
# Out:
#   File "<tokenize>", line 7
#     final.plot.barh(x = "Platform" , figsize=(15,7) , color = "red", title = "% ")
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
final.plot.barh(x = "Platform" , figsize=(15,7) , color = "red", title = "% ")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-f29cf54f6f55> in <module>
# ----> 1 final.plot.barh(x = "Platform" , figsize=(15,7) , color = "red", title = "% ")
#
# D:\ProgramFiles\lib\site-packages\pandas\plotting\_core.py in barh(self, x, y, **kwargs)
#    1214         other axis represents a measured value.
#    1215         """
# -> 1216         return self(kind="barh", x=x, y=y, **kwargs)
#    1217
#    1218     def box(self, by=None, **kwargs):
#
# D:\ProgramFiles\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# D:\ProgramFiles\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# D:\ProgramFiles\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     293         for ax in self.axes:
#     294             self._post_plot_logic_common(ax, self.data)
# --> 295             self._post_plot_logic(ax, self.data)
#     296
#     297     def _args_adjust(self):
#
# D:\ProgramFiles\lib\site-packages\pandas\plotting\_matplotlib\core.py in _post_plot_logic(self, ax, data)
#    1526         name = self._get_index_name()
#    1527
# -> 1528         s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    1529         e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    1530
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
plt.show()

# %%
buraya kadar birleştir
# Out:
#   File "<ipython-input-26-8eaecbbdb470>", line 1
#     buraya kadar birleştir
#                ^
# SyntaxError: invalid syntax

# %%
#çıkan oyun sayısının platformda çıkan diğer oyunlarla arasındaki yüzdelik..

# %% [markdown]
# ## #Piyasada Yayınlanan Oyun Türlerinin Yüzdesi

# %%
genre_df =  df[["Genre"]]
genre_group =  genre_df.groupby(['Genre']).size().reset_index()
genre_group.plot(kind='pie', y = 0 , autopct='%1.1f%%',  title = "Published Game Types",
startangle=90, shadow=False, labels=genre_group['Genre'], legend = False, fontsize=14, figsize=(10, 10))
plt.show()

# %%
buray kadar birleştir
# Out:
#   File "<ipython-input-29-93986999d0e2>", line 1
#     buray kadar birleştir
#               ^
# SyntaxError: invalid syntax

# %%
#Piyasadaki oyun türlerinin yüzdeleri üstteki

# %%
gs_gnr_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-eba0f10090d2> in <module>
# ----> 1 gs_gnr_df
#
# NameError: name 'gs_gnr_df' is not defined

# %%
gs_gnr_df.groupby(['Genre']).mean().reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-cfdc4c792aae> in <module>
# ----> 1 gs_gnr_df.groupby(['Genre']).mean().reset_index()
#
# NameError: name 'gs_gnr_df' is not defined

# %%
gs_gnr_df =  df[["Genre","Global_Sales"]]
gb_group_sum =  gs_gnr_df.groupby(['Genre']).sum().reset_index()
gb_group_mean =  gs_gnr_df.groupby(['Genre']).mean().reset_index()


gb_group_sum.plot(kind='pie', y = "Global_Sales" , autopct='%1.1f%%',  title = "Percentages of The Game Types Sold in The Market",startangle=90,
 shadow=False, labels=gb_group_sum['Genre'], legend = False, fontsize=14, figsize=(10, 10))
plt.show()

# %% [markdown]
# Piyasadaki Satılan oyunların yüzdeleri

# %% [markdown]
# ## piyasadaki oyun türüne göre oyunların satış yüzdeleri

# %%
gb_group_mean.plot(kind='pie', y = "Global_Sales" , autopct='%1.1f%%',  title = "Game Sales Percents According to Game Type",startangle=90,
 shadow=False, labels=gb_group_mean['Genre'], legend = False, fontsize=14, figsize=(10, 10))
plt.show()

# %% [markdown]
# ------------
# # #Disburution of Global Sales Which Game Type is Platform

# %%
df_globalsales_platform =  gs_gnr_df[gs_gnr_df.Genre == "Platform"]    
sns.distplot(df_globalsales_platform['Global_Sales']);   
fig = plt.figure()
res = stats.probplot(df_globalsales_platform['Global_Sales'], plot=plt)
plt.show()
# Out:
# D:\ProgramFiles\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## This Graphic is Same With Previous One but Only Lesser than Seven Million Sold Games

# %%
df_genre_global_7.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-13f1b2f4c9b3> in <module>
# ----> 1 df_genre_global_7.shape
#
# NameError: name 'df_genre_global_7' is not defined

# %%
df_genre_global_7[df_genre_global_7["Global_Sales"]>3].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-f500a69de2aa> in <module>
# ----> 1 df_genre_global_7[df_genre_global_7["Global_Sales"]>3].shape
#
# NameError: name 'df_genre_global_7' is not defined

# %%
df_globalsales_platform_7 = gs_gnr_df[(gs_gnr_df["Global_Sales"]<7) & (gs_gnr_df.Genre=="Platform") ]

# %%
df_globalsales_platform_7 = gs_gnr_df[(gs_gnr_df["Global_Sales"]<7) & (gs_gnr_df.Genre=="Platform") ]
sns.distplot(df_globalsales_platform_7['Global_Sales']);   
fig = plt.figure()
res = stats.probplot(df_globalsales_platform_7['Global_Sales'], plot=plt)
plt.show()
# Out:
# D:\ProgramFiles\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## This Graphic is Same With Previous One but Only Lesser than One Million Sold Games

# %%
df_globalsales_platform_1 = gs_gnr_df[(gs_gnr_df["Global_Sales"]<1) & (gs_gnr_df.Genre=="Platform") ]
sns.distplot(df_globalsales_platform_1['Global_Sales']);   
fig = plt.figure()
res = stats.probplot(df_globalsales_platform_1['Global_Sales'], plot=plt)
plt.show()
# Out:
# D:\ProgramFiles\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## This Graphic is Same With Previous One but Only Lesser than 0.2 Million Sold Games

# %%
df_globalsales_platform_0_2 = gs_gnr_df[(gs_gnr_df["Global_Sales"]<0.2) & (gs_gnr_df.Genre=="Platform") ]
sns.distplot(df_globalsales_platform_0_2['Global_Sales']);   
fig = plt.figure()
res = stats.probplot(df_globalsales_platform_1['Global_Sales'], plot=plt)
plt.show()
# Out:
# D:\ProgramFiles\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Groupped According to Global Sales in Some Levels

# %%
df_genre_global_grupby = gs_gnr_df.copy()
df_genre_global_grupby['grup'] = pd.Series(len(df_genre_global_grupby['Global_Sales']), index=df_genre_global_grupby.index)
df_genre_global_grupby['grup'] = 0 

df_genre_global_grupby.loc[ df_genre_global_grupby['Global_Sales'] <= 0.05, 'grup']= 0
df_genre_global_grupby.loc[(df_genre_global_grupby['Global_Sales'] > 0.05) & (df_genre_global_grupby['Global_Sales'] <= 0.1), 'grup'] = 1
df_genre_global_grupby.loc[(df_genre_global_grupby['Global_Sales'] > 0.1) & (df_genre_global_grupby['Global_Sales'] <= 0.2), 'grup']= 2
df_genre_global_grupby.loc[(df_genre_global_grupby['Global_Sales'] > 0.2) & (df_genre_global_grupby['Global_Sales'] <= 0.5), 'grup']= 3
df_genre_global_grupby.loc[(df_genre_global_grupby['Global_Sales'] > 0.5) & (df_genre_global_grupby['Global_Sales'] <= 1), 'grup']= 4
df_genre_global_grupby.loc[(df_genre_global_grupby['Global_Sales'] > 1) & (df_genre_global_grupby['Global_Sales'] <= 5), 'grup']= 5
df_genre_global_grupby.loc[ df_genre_global_grupby['Global_Sales'] > 5, 'grup']= 6

print(df_genre_global_grupby.groupby("grup").count())

sns.distplot(df_genre_global_grupby['grup']);   
fig = plt.figure()
res = stats.probplot(df_genre_global_grupby['grup'], plot=plt)
plt.show()
# Out:
#       Genre  Global_Sales
# grup
# 0      3858          3859
# 1      2448          2448
# 2      2913          2913
# 3      3562          3562
# 4      1880          1880
# 5      1849          1850
# 6       207           207
# D:\ProgramFiles\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_genre_global_grupby['grup'] = df_genre_global_grupby['grup'].astype('str')
df_genre_global_grupby.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Genre         16717 non-null  object
#  1   Global_Sales  16719 non-null  float64
#  2   grup          16719 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 392.0+ KB

# %% [markdown]
# # YILLARA GÖRE SATILAN OYUN SAYISI - Number of Sold Games According to Years

# %%
yearly_sales =  df[["Name","Year_of_Release"]]
yearly_sales_df =yearly_sales.groupby(['Year_of_Release']).count()

yearly_global = df[["Name","Year_of_Release","Global_Sales"]]
yearly_global_df = yearly_global.groupby(["Year_of_Release"])[["Global_Sales"]].sum()

sales_yearly=pd.concat([yearly_global_df,yearly_sales_df ],axis=1).reset_index()

sales_yearly.plot.line(x='Year_of_Release', y='Global_Sales')
plt.show()

# %% [markdown]
# # YILLARA GÖRE YAYINLANMIŞ OYUN SAYISI - # Number of Published Games According to Years

# %%
sales_yearly.plot.line(x='Year_of_Release', y='Name')
plt.show()

# %% [markdown]
# ## KITALARA GÖRE KONSOL TERCİHLERİ

# %%
toplam_platform_NA_EU_JP=df.groupby(['Platform'])[["NA_Sales","EU_Sales","JP_Sales"]].sum().reset_index()
a = toplam_platform_NA_EU_JP[["NA_Sales","EU_Sales","JP_Sales"]] / toplam_platform_NA_EU_JP[["NA_Sales","EU_Sales","JP_Sales"]].sum()

print(toplam_platform_NA_EU_JP)
plat_sum = df[["Platform"]]
plat_sum = plat_sum.groupby(["Platform"]).size().reset_index()

deneme = pd.concat([a,plat_sum["Platform"]],axis=1)

plt.figure(figsize=(30,10))
line = sns.lineplot(data=deneme, x="Platform", y="NA_Sales", marker="o", label= "NA_Sales")
line = sns.lineplot(data=deneme, x="Platform", y="EU_Sales", marker="o", label= "EU_Sales")
line = sns.lineplot(data=deneme, x="Platform", y="JP_Sales", marker="o", label= "JP_Sales")

line.set(xticks=deneme.Platform.values)
line.set(ylabel="Percent")
plt.show()
# Out:
#    Platform  NA_Sales  EU_Sales  JP_Sales
# 0      2600     90.60      5.47      0.00
# 1       3DO      0.00      0.00      0.10
# 2       3DS     83.49     61.48    100.67
# 3        DC      5.43      1.69      8.56
# 4        DS    382.67    188.89    175.57
# 5        GB    114.32     47.82     85.12
# 6       GBA    187.54     75.25     47.33
# 7        GC    133.46     38.71     21.58
# 8       GEN     21.05      6.05      2.70
# 9        GG      0.00      0.00      0.04
# 10      N64    139.02     41.06     34.22
# 11      NES    125.94     21.15     98.65
# 12       NG      0.00      0.00      1.44
# 13       PC     94.53    142.44      0.17
# 14     PCFX      0.00      0.00      0.03
# 15       PS    336.52    213.61    139.82
# 16      PS2    583.84    339.29    139.20
# 17      PS3    393.49    330.29     80.19
# 18      PS4    108.74    141.09     16.00
# 19      PSP    109.17     66.68     76.78
# 20      PSV     12.58     13.12     21.93
# 21      SAT      0.72      0.54     32.26
# 22      SCD      1.00      0.36      0.45
# 23     SNES     61.23     19.04    116.55
# 24     TG16      0.00      0.00      0.16
# 25       WS      0.00      0.00      1.42
# 26      Wii    496.90    262.21     69.33
# 27     WiiU     38.10     25.13     13.01
# 28     X360    602.47    270.76     12.43
# 29       XB    186.69     60.95      1.38
# 30     XOne     93.12     51.59      0.34

# %% [markdown]
# ## KITALARA VE OYUN TÜRLERİNE GÖRE SATIŞ MİKTARLARI

# %%
toplam_genre_NA_EU_JP=df.groupby(['Genre'])[["NA_Sales","EU_Sales","JP_Sales"]].sum().reset_index()
toplam_genre = toplam_genre_NA_EU_JP[["NA_Sales","EU_Sales","JP_Sales"]] / toplam_genre_NA_EU_JP[["NA_Sales","EU_Sales","JP_Sales"]].sum()

print(toplam_genre_NA_EU_JP)
genre_sum = df[["Genre"]]
genre_sum = genre_sum.groupby(["Genre"]).size().reset_index()

genre_sales = pd.concat([toplam_genre,genre_sum["Genre"]],axis=1)

plt.figure(figsize=(30,10))
line = sns.lineplot(data=genre_sales, x="Genre", y="NA_Sales", marker="o", label= "NA_Sales")
line = sns.lineplot(data=genre_sales, x="Genre", y="EU_Sales", marker="o", label= "EU_Sales")
line = sns.lineplot(data=genre_sales, x="Genre", y="JP_Sales", marker="o", label= "JP_Sales")


line.set(xticks=genre_sales.Genre.values)
line.set(ylabel="Percent")
plt.show()
# Out:
#            Genre  NA_Sales  EU_Sales  JP_Sales
# 0         Action    879.01    519.13    161.44
# 1      Adventure    105.26     63.54     52.30
# 2       Fighting    223.36    100.33     87.48
# 3           Misc    407.27    212.74    108.11
# 4       Platform    445.50    200.35    130.83
# 5         Puzzle    122.87     50.01     57.31
# 6         Racing    359.35    236.51     56.71
# 7   Role-Playing    330.81    188.71    355.46
# 8        Shooter    592.24    317.34     38.76
# 9     Simulation    182.19    113.52     63.80
# 10        Sports    684.43    376.79    135.54
# 11      Strategy     68.55     45.17     49.66

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
df.head(5)
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN
